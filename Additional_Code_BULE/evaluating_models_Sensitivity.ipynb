# %% [markdown]
# ### Heatmaps for Sensitivity
#
#
# the plots displayed in this file are used to inspect the effect of reducing the amount of training data on the performance
#
# - heatmap for sensitivity analysis

# %%
#activate conda env AutencoderTF env tf '2.10.0' , python 3.9.16
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import matplotlib.pyplot as plt


print(sys.path)
sys.path.append('/root/LatentOE-AD')
from Additional_Code_BULE.loe_utils.plots_from_paper_functions import *
from Additional_Code_BULE.utils.helper_functions  import plot_precision_recall_multi,plot_pr_ntl
# Out:
# ['/root/LatentOE-AD/Additional_Code_BULE', '/root/LatentOE-AD/Additional_Code_BULE/c', '/root/LatentOE-AD/Additional_Code_BULE/\\\\Users\\\\buehl\\\\git\\\\projects\\\\LatentOE-AD', '/root/anaconda3/envs/AutencoderTF/lib/python39.zip', '/root/anaconda3/envs/AutencoderTF/lib/python3.9', '/root/anaconda3/envs/AutencoderTF/lib/python3.9/lib-dynload', '', '/root/anaconda3/envs/AutencoderTF/lib/python3.9/site-packages']
# /root/anaconda3/envs/AutencoderTF/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-08-21 13:44:03.898173: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 13:44:03.978619: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-21 13:44:03.995823: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-08-21 13:44:04.359128: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-08-21 13:44:04.359157: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-08-21 13:44:04.359160: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
folderpath='/root/LatentOE-AD/RESULTS/fmnist/'
model='loe_hard'
mode='all'
#contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
contlist=[0.0,0.05,0.1,0.15,0.2]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
df
# Out:
#     alpha0  alpha       auc
# 0     0.00   0.00  0.948223
# 1     0.00   0.05  0.944183
# 2     0.00   0.10  0.929694
# 3     0.00   0.15  0.888043
# 4     0.00   0.20  0.862316
# 5     0.05   0.00  0.913974
# 6     0.05   0.05  0.930353
# 7     0.05   0.10  0.901159
# 8     0.05   0.15  0.901159
# 9     0.05   0.20  0.872878
# 10    0.10   0.00  0.890040
# 11    0.10   0.05  0.907076
# 12    0.10   0.10  0.926952
# 13    0.10   0.15  0.923056
# 14    0.10   0.20  0.887369
# 15    0.15   0.00  0.869049
# 16    0.15   0.05  0.883571
# 17    0.15   0.10  0.908066
# 18    0.15   0.15  0.924671
# 19    0.15   0.20  0.912125
# 20    0.20   0.00  0.864717
# 21    0.20   0.05  0.864717
# 22    0.20   0.10  0.890239
# 23    0.20   0.15  0.907963
# 24    0.20   0.20  0.912390

# %%
folderpath='/root/LatentOE-AD/RESULTS/fmnist_0.6/'
model='loe_soft'
mode='all'
contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
contlist=[0.0,0.05,0.1,0.15,0.2]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}, 60% of trainingdata',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
folderpath='/root/LatentOE-AD/RESULTS/fmnist_0.01/'
model='refine'
mode='all'
contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
#contlist=[0.0,0.05,0.1,0.15,0.2]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}, 1% of trainingdata',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
folderpath='/root/LatentOE-AD/RESULTS/fmnist_0.1/'
model='refine'
mode='all'
contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
#contlist=[0.0,0.05,0.1,0.15,0.2]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}, 10% of trainingdata',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
folderpath='/root/LatentOE-AD/RESULTS/fmnist_0.3/'
model='refine'
mode='all'
contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
#contlist=[0.0,0.05,0.1,0.15,0.2]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}, 30% of trainingdata',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
folderpath='/root/LatentOE-AD/RESULTS/fmnist/'
model='refine'
mode='all'
contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
#contlist=[0.0,0.05,0.1,0.15,0.2]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}, 100% of trainingdata',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
# comparing multiple runs of the same model oneclassSVM
plt.rcParams["figure.figsize"] = (25, 10)  # Adjust the figure size as per your preference

MODEL_RESULT_PATH = Path(r"/root/LatentOE-AD/RESULTS/fmnist/refine_assumed_contam_0.1_allresults")

# load the diffent runs in a list
nameslist,dataframe_list=[name for name in os.listdir(MODEL_RESULT_PATH) if "allresults_run_"in name],[]
for name in nameslist:
    dataframe_list.append(pd.read_pickle(os.path.join(MODEL_RESULT_PATH,name)))

# for which contamination ratios we want to see the results
contam_list = [0.0, 0.1, 0.2,0.3,0.4]

title='NTL refine Precision-Recall Curves for Fashion MNIST different contamination ratios , assumed contamination is 0.1'

plot_precision_recall_multi(dataframe_list,plot=True,contam_list=contam_list,show_img=True,sklearn_pr=False,title=title,pred_y='score_')
# Out:
# |████████████████████████████████████████| 10/10 [100%] in 26.6s (0.36/s)
# /root/LatentOE-AD/Additional_Code_BULE/utils/helper_functions.py:304: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
# comparing multiple runs of the same model oneclassSVM
plt.rcParams["figure.figsize"] = (25, 10)  # Adjust the figure size as per your preference

MODEL_RESULT_PATH = Path(r"/root/LatentOE-AD/RESULTS/fmnist_0.01/refine_assumed_contam_0.1_allresults")

# load the diffent runs in a list
nameslist,dataframe_list=[name for name in os.listdir(MODEL_RESULT_PATH) if "allresults_run_"in name],[]
for name in nameslist:
    dataframe_list.append(pd.read_pickle(os.path.join(MODEL_RESULT_PATH,name)))

# for which contamination ratios we want to see the results
contam_list = [0.0, 0.1, 0.2,0.3,0.4]

title='NTL refine Precision-Recall Curves for Fashion MNIST on 1% training data  different contamination ratios , assumed contamination is 0.1'

plot_precision_recall_multi(dataframe_list,plot=True,contam_list=contam_list,show_img=True,sklearn_pr=False,title=title,pred_y='score_')
# Out:
# |████████████████████████████████████████| 10/10 [100%] in 26.6s (0.36/s)
# /root/LatentOE-AD/Additional_Code_BULE/utils/helper_functions.py:304: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
# comparing multiple runs of the same model oneclassSVM
plt.rcParams["figure.figsize"] = (25, 10)  # Adjust the figure size as per your preference

MODEL_RESULT_PATH = Path(r"/root/LatentOE-AD/RESULTS/fmnist/simple_refine_assumed_contam_0.0_allresults")

# load the diffent runs in a list
nameslist,dataframe_list=[name for name in os.listdir(MODEL_RESULT_PATH) if "allresults_run_"in name],[]
for name in nameslist:
    dataframe_list.append(pd.read_pickle(os.path.join(MODEL_RESULT_PATH,name)))

# for which contamination ratios we want to see the results
contam_list = [0.0, 0.1, 0.2,0.3,0.4]

title='NTL simple_refine Precision-Recall Curves for Fashion MNIST on 1% training data  different contamination ratios , assumed contamination is 0.1'

plot_precision_recall_multi(dataframe_list,plot=True,contam_list=contam_list,show_img=True,sklearn_pr=False,title=title,pred_y='score_')
# Out:
# |████████████████████████████████████████| 10/10 [100%] in 26.5s (0.36/s)
# /root/LatentOE-AD/Additional_Code_BULE/utils/helper_functions.py:304: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
## only 0.0 0.15 fails

folderpath='/root/LatentOE-AD/RESULTS/fmnist_0.1/'
model='simple_refine'
mode='all'
contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
#contlist=[0.05,0.1,0.15,0.2,0.3,0.4]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}, 10% of trainingdata',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
## only 0.0 0.15 fails

folderpath='/root/LatentOE-AD/RESULTS/fmnist_0.1/'
model='simple_refine'
mode='all'
contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
contlist=[0.05,0.1,0.15,0.2,0.3,0.4]
df=get_heatmap_df(folderpath,model,contlist,mode=mode)
plot_heatmap(df,title=f'AUROC {model} - {mode}, 10% of trainingdata',vmin_max=(0.6,1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0','alpha',  'auc')

# %%
# comparing multiple runs of the same model oneclassSVM
plt.rcParams["figure.figsize"] = (25, 10)  # Adjust the figure size as per your preference

MODEL_RESULT_PATH = Path(r"/root/LatentOE-AD/RESULTS/fmnist/simple_refine_assumed_contam_0.0_allresults")

# load the diffent runs in a list
nameslist,dataframe_list=[name for name in os.listdir(MODEL_RESULT_PATH) if "allresults_run_"in name],[]
for name in nameslist:
    dataframe_list.append(pd.read_pickle(os.path.join(MODEL_RESULT_PATH,name)))

# for which contamination ratios we want to see the results
contam_list = [0.0, 0.05]

title='NTL refine Precision-Recall Curves for Fashion MNIST on 1% training data  different contamination ratios , assumed contamination is 0.1'

plot_precision_recall_multi(dataframe_list,plot=True,contam_list=contam_list,show_img=True,sklearn_pr=False,title=title,pred_y='score_')
# Out:
# |                                        | ▁▃▅ 0/10 [0%] in 0s (~0s, 0.0/s)
# |████████████████████████████████████████| 10/10 [100%] in 10.6s (0.90/s)
# /root/LatentOE-AD/Additional_Code_BULE/utils/helper_functions.py:304: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
# plot multiple heatmaps

folderpathlist=['/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist_0.1/','/root/LatentOE-AD/RESULTS/fmnist_0.01/']
model='refine'
mode='all'

#overall_title = f'AUROC {model} - {mode}'
overall_title = f'AUROC - Refine - Average '

titles = ["100 %", "10%", "1%"]


contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
df_list=[]
for folderpath in folderpathlist:
    df=get_heatmap_df(folderpath,model,contlist,mode=mode)
    df_list.append(df)


plot_heatmap_multiple(df_list, titles=titles,overall_title=overall_title, vmin_max=(0.6, 1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:225: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0', 'alpha', 'auc')
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:258: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
# plot multiple heatmaps

folderpathlist=['/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist_0.1/','/root/LatentOE-AD/RESULTS/fmnist_0.01/']
model='simple_refine'
mode='all'

overall_title = f'AUROC {model} - {mode}'
titles = ["100 %", "10%", "1%"]


contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
df_list=[]
for folderpath in folderpathlist:
    df=get_heatmap_df(folderpath,model,contlist,mode=mode)
    df_list.append(df)


plot_heatmap_multiple(df_list, titles=titles,overall_title=overall_title, vmin_max=(0.6, 1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:225: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0', 'alpha', 'auc')
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:258: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
# plot multiple heatmaps

folderpathlist=['/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist_0.1/','/root/LatentOE-AD/RESULTS/fmnist_0.01/','/root/LatentOE-AD/RESULTS/fmnist_0.001/']
model='simple_refine'
mode='all'

overall_title = f'AUROC {model} - {mode}'
titles = ["100 %", "10%", "1%", "0.1%"]


contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
df_list=[]
for folderpath in folderpathlist:
    df=get_heatmap_df(folderpath,model,contlist,mode=mode)
    df_list.append(df)


plot_heatmap_multiple(df_list, titles=titles,overall_title=overall_title, vmin_max=(0.6, 1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:225: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0', 'alpha', 'auc')
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:258: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
## TODO make a column with the same color as the heatmaps for every trainingset of blind. 

# plot multiple heatmaps


#blind with 100% of the data
[0.9482227333333333,0.9139738877777777,0.890040021111111,0.8690490733333334,0.8510804133333334,0.8137161555555557,0.7735875833333333]

folderpathlist=['/root/LatentOE-AD/RESULTS/fmnist/']
model='blind'
mode='all'

overall_title = f'AUROC {model} - {mode}'
titles = ["100 %"]


contlist=[0.1]
df_list=[]
for folderpath in folderpathlist:
    df=get_heatmap_df(folderpath,model,contlist,mode=mode)
    df_list.append(df)

df_list
#plot_heatmap_multiple(df_list, titles=titles,overall_title=overall_title, vmin_max=(0.6, 1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 14
#      12 df_list=[]
#      13 for folderpath in folderpathlist:
# ---> 14     df=get_heatmap_df(folderpath,model,contlist,mode=mode)
#      15     df_list.append(df)
#      17 df_list
#
# File ~/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:111, in get_heatmap_df(folderpath, model, contlist, mode)
#     109 for a0,a in zip(alpha0,alpha):
#     110     filepath=get_path_from_abspathlist(model,a0,a,abspath_list_results)
# --> 111     with open(filepath) as f:
#     112         results = f.read()
#     113         if mode=='all':
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
# plot multiple heatmaps

folderpathlist=['/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist/']
model='refine'
mode='all'

#overall_title = f'AUROC {model} '

overall_title = f'AUROC - Refine'

titles = ["Maximum", "Average", "Minimum"]
modes=['max','all','min']


contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
df_list=[]
for folderpath, mode in zip(folderpathlist,modes):
    df=get_heatmap_df(folderpath,model,contlist,mode=mode)
    df_list.append(df)


plot_heatmap_multiple(df_list, titles=titles,overall_title=overall_title, vmin_max=(0.6, 1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:225: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0', 'alpha', 'auc')
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:258: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
# plot multiple heatmaps

folderpathlist=['/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist/']
model='loe_soft'
mode='all'

overall_title = f'AUROC {model} '
overall_title = f'AUROC - LOE Soft'

titles = ["Maximum", "Average", "Minimum"]
modes=['max','all','min']


contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
df_list=[]
for folderpath, mode in zip(folderpathlist,modes):
    df=get_heatmap_df(folderpath,model,contlist,mode=mode)
    df_list.append(df)


plot_heatmap_multiple(df_list, titles=titles,overall_title=overall_title, vmin_max=(0.6, 1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:225: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0', 'alpha', 'auc')
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:258: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])

# %%
# plot multiple heatmaps

folderpathlist=['/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist/','/root/LatentOE-AD/RESULTS/fmnist/']
model='loe_hard'
mode='all'

overall_title = f'AUROC {model} '
overall_title = f'AUROC - LOE Hard'

titles = ["Maximum", "Average", "Minimum"]
modes=['max','all','min']


contlist=[0.0,0.05,0.1,0.15,0.2,0.3,0.4]
df_list=[]
for folderpath, mode in zip(folderpathlist,modes):
    df=get_heatmap_df(folderpath,model,contlist,mode=mode)
    df_list.append(df)


plot_heatmap_multiple(df_list, titles=titles,overall_title=overall_title, vmin_max=(0.6, 1))
# Out:
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:225: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df.pivot('alpha0', 'alpha', 'auc')
# /root/LatentOE-AD/Additional_Code_BULE/loe_utils/plots_from_paper_functions.py:258: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 0.95])
